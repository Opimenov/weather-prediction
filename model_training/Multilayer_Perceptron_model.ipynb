# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

# %%
#read in provided data
provided_data = np.load('data/data_selected_1980_2010.npy')
target = np.load('data/target_1980_2010.npy')

# %%
#check the dimensions of provided data
provided_data.shape
# Out:
# (11300, 4)

# %%
#target has two columns and we only need one
target.shape
# Out:
# (11300, 2)

# %%
#make it so that there is only one column in target
target = target[:,1].reshape(11300,1)

# %%
#check the result
print (target)
# Out:
# [[ 0.]
#  [ 0.]
#  [ 0.]
#  ...,
#  [ 0.]
#  [ 0.]
#  [ 0.]]

# %%
for i in range(target.shape[0]):
    if (target[i,:] <> 0):
        print i
# Out:
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 142
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 215
# 516
# 517
# 518
# 526
# 527
# 528
# 549
# 550
# 551
# 843
# 844
# 845
# 851
# 852
# 853
# 854
# 855
# 856
# 857
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 1249
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# 1259
# 1260
# 1261
# 1262
# 1263
# 1334
# 1560
# 1561
# 1562
# 1563
# 1602
# 1603
# 1604
# 1605
# 1606
# 1607
# 1608
# 1609
# 1610
# 1611
# 1612
# 1613
# 1614
# 1728
# 1729
# 1730
# 1731
# 1732
# 1733
# 1734
# 1735
# 1736
# 1738
# 1739
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2304
# 2305
# 2306
# 2307
# 2308
# 2309
# 2310
# 2314
# 2358
# 2359
# 2360
# 2361
# 2362
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# 2437
# 2438
# 2439
# 2440
# 2441
# 2442
# 2443
# 2444
# 2445
# 2446
# 2447
# 2725
# 2726
# 2727
# 2728
# 2729
# 2730
# 2731
# 2732
# 2733
# 2734
# 2735
# 2736
# 2761
# 2762
# 2763
# 2764
# 2765
# 2766
# 2770
# 2771
# 2772
# 2773
# 2774
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3702
# 3703
# 3704
# 3705
# 3706
# 3707
# 3708
# 3709
# 3773
# 3774
# 3795
# 3796
# 3797
# 3798
# 3799
# 3800
# 3801
# 3802
# 3803
# 3804
# 3805
# 3806
# 3807
# 3808
# 3809
# 3810
# 3831
# 3832
# 3833
# 3836
# 3837
# 3838
# 3839
# 3840
# 3841
# 3842
# 3843
# 4103
# 4104
# 4105
# 4106
# 4110
# 4148
# 4149
# 4150
# 4151
# 4159
# 4552
# 4553
# 4554
# 4555
# 4556
# 4557
# 4558
# 4559
# 4560
# 4561
# 4562
# 4563
# 4564
# 4565
# 4566
# 4567
# 4616
# 4617
# 4618
# 4619
# 4620
# 4621
# 4622
# 4856
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4900
# 4901
# 4902
# 4903
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# 4915
# 4916
# 4917
# 4918
# 4919
# 4920
# 4921
# 4922
# 4923
# 4924
# 4925
# 4926
# 4927
# 4928
# 4929
# 4930
# 4931
# 4932
# 4933
# 4936
# 4937
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965
# 4966
# 5263
# 5264
# 5265
# 5266
# 5267
# 5611
# 5950
# 5951
# 5952
# 5953
# 5963
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5978
# 5979
# 6366
# 6648
# 6649
# 6650
# 6653
# 6716
# 6717
# 6718
# 6719
# 6720
# 6721
# 6722
# 6723
# 6724
# 6725
# 6726
# 6727
# 6728
# 6729
# 6730
# 6731
# 6732
# 6733
# 6734
# 6841
# 7021
# 7022
# 7023
# 7028
# 7056
# 7057
# 7058
# 7059
# 7060
# 7061
# 7077
# 7078
# 7079
# 7080
# 7081
# 7082
# 7127
# 7456
# 7457
# 7458
# 7459
# 7460
# 7465
# 7466
# 7467
# 7468
# 7469
# 7470
# 7472
# 7771
# 7772
# 7773
# 7777
# 7778
# 7779
# 7780
# 7781
# 7782
# 7783
# 7812
# 8228
# 8230
# 8231
# 8240
# 8241
# 8246
# 8247
# 8248
# 8249
# 8505
# 8506
# 8507
# 8508
# 8509
# 8510
# 8511
# 8564
# 8565
# 8566
# 8567
# 8884
# 8885
# 8886
# 8887
# 8888
# 8889
# 8890
# 8891
# 8892
# 8893
# 8894
# 8895
# 8896
# 8897
# 8898
# 8899
# 8935
# 8936
# 8937
# 8938
# 8939
# 8940
# 9693
# 9695
# 9696
# 9697
# 9698
# 9699
# 9700
# 9963
# 9964
# 9965
# 9966
# 10058
# 10059
# 10064
# 10065
# 10066
# 10067
# 10068
# 10069
# 10070
# 10071
# 10072
# 10073
# 10074
# 10075
# 10076
# 10077
# 10078
# 10079
# 10080
# 10081
# 10082
# 10083
# 10084
# 10129
# 10130
# 10132
# 10318
# 10357
# 10358
# 10359
# 10360
# 10361
# 10362
# 10363
# 10364
# 10365
# 10366
# 10367
# 10368
# 10369
# 10370
# 10371
# 10372
# 10373
# 10374
# 10375
# 10376
# 10405
# 10697
# 10739
# 10740
# 10741
# 10808
# 10809
# 11095
# 11096
# 11097
# 11098
# 11099
# 11100
# 11101
# 11102
# 11103
# 11104
# 11105
# 11106
# 11107
# 11108
# 11109
# 11110
# 11111
# 11112
# 11113
# 11114
# 11115
# 11116
# 11117
# 11118
# 11119
# 11120
# 11121
# 11122
# 11136
# 11137
# 11138
# 11139
# 11140
# 11141
# 11142
# 11143
# 11144
# 11145
# 11146
# 11147
# 11148
# 11149
# 11150
# 11155
# 11156
# 11157
# 11158
# 11159
# 11200
# 11201
# 11202
# 11203
# 11204
# 11205

# %%
#let's split the date to train and test 
X_train = provided_data[:9497,:]
X_test = provided_data[9497:,:]
y_train = target[:9497,:]
y_test = target[9497:,:]

# %%
#check the results
print X_train.shape
print X_test.shape
print y_train.shape
print y_test.shape
# Out:
# (9497, 4)
# (1803, 4)
# (9497, 1)
# (1803, 1)

# %%
#now it is time to normalize the data (i.e. scale it)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# give scaler some more info to work with
scaler.fit(X_train)
# Out:
# /Users/bovcontrolboston/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype |S32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
#now transform the data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#try to train the model
mlp = MLPClassifier(hidden_layer_sizes=(100,))
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(4,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
#let's try our model
predictions = mlp.predict(X_test)

# %%
#now is the time to evaluate how we did
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test,predictions))
# Out:
# [[1684    0]
#  [ 119    0]]
#              precision    recall  f1-score   support
#
#         0.0       0.93      1.00      0.97      1684
#         1.0       0.00      0.00      0.00       119
#
# avg / total       0.87      0.93      0.90      1803

# %%
from sklearn import metrics
fpr,tpr,thresholds = metrics.roc_curve(y_test, predictions, pos_label=2)

# %%
print fpr
print tpr
# Out:
# [ 0.  1.]
# [ nan  nan]

# %%
roc_auc = metrics.auc(fpr,tpr)

# %%
import matplotlib.pyplot as plt
plt.figure()
lw = 2
plt.plot(fpr[2], tpr[2], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-8e9abffb602b> in <module>()
#       2 plt.figure()
#       3 lw = 2
# ----> 4 plt.plot(fpr[2], tpr[2], color='darkorange',
#       5          lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[2])
#       6 plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
